# %%
import numpy as np
import pandas as pd
from plotnine import ggplot, aes, geom_line, geom_point, labs, geom_boxplot

# %%
#Reading the file
dataframe1=pd.read_csv(r"E:Revanth Reddy\\Durham Weather Data.csv", low_memory=False)

# %%
#Lineplot
ggplot(dataframe1) + aes(x="MONTHS", y="SUN_DUR") + geom_line()
# Out:
# <ggplot: (136686529356)>

# %%
#Boxplot
from plotnine import geom_boxplot
ggplot(dataframe1) + aes(x="MONTHS", y="AF_DAYS") + geom_boxplot()
# Out:
# <ggplot: (136687127031)>

# %%
#Boxplot
ggplot(dataframe1) + aes(x="MONTHS", y="RAIN") + geom_boxplot()
# Out:
# <ggplot: (136687316833)>
